# %%
import pandas as pd

# %%
import string

# %%
string.ascii_uppercase
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
df = pd.read_csv('hand_landmarks.csv', header=None)

# %%
df.head()
# Out:
#   0         1         2             3         4         5         6   \
# 0  A  0.634460  0.709621 -6.232813e-07  0.570094  0.639672 -0.025391
# 1  A  0.635324  0.711340 -6.168005e-07  0.570395  0.643783 -0.027195
# 2  A  0.636526  0.712531 -6.047676e-07  0.571669  0.647535 -0.026985
# 3  A  0.638128  0.712998 -6.125114e-07  0.572956  0.646976 -0.027835
# 4  A  0.640194  0.714050 -6.307072e-07  0.573752  0.646886 -0.027969
#
#          7         8         9   ...        54        55        56        57  \
# 0  0.528824  0.504352 -0.027754  ...  0.004624  0.671311  0.388483 -0.006619
# 1  0.529158  0.508795 -0.030260  ...  0.004732  0.672147  0.392487 -0.006497
# 2  0.529570  0.512910 -0.030838  ...  0.003180  0.672339  0.395214 -0.008192
# 3  0.530409  0.513451 -0.031520  ...  0.004795  0.672410  0.392849 -0.006528
# 4  0.530767  0.511462 -0.030503  ...  0.005983  0.673960  0.393947 -0.005131
#
#          58        59        60        61        62        63
# 0  0.659070  0.457405  0.007862  0.660128  0.471686  0.023103
# 1  0.660715  0.460905  0.008325  0.662331  0.472947  0.023772
# 2  0.661249  0.463534  0.007035  0.662302  0.474809  0.022853
# 3  0.661802  0.462110  0.008547  0.663779  0.474147  0.024317
# 4  0.663768  0.463176  0.009415  0.665350  0.475644  0.024546
#
# [5 rows x 64 columns]

# %%
df[0].value_counts()
# Out:
# 0
# A    136
# B     90
# C     90
# Name: count, dtype: int64

# %%
indices = {}

# %%
for c in string.ascii_uppercase:
    indices[c] = df[df[0]==c].index

for i in indices:
    df = df.drop(indices[i][100:])

# %%
df[0].value_counts()
# Out:
# 0
# A    100
# B     90
# C     90
# Name: count, dtype: int64

# %%
len(df)
# Out:
# 280

# %%
X = df[list(range(1, 64))]
y = df[0]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
y_train[:20]
# Out:
# 27     A
# 173    B
# 145    B
# 293    C
# 270    C
# 90     A
# 37     A
# 235    C
# 207    B
# 182    B
# 227    C
# 244    C
# 180    B
# 217    B
# 162    B
# 250    C
# 196    B
# 160    B
# 236    C
# 44     A
# Name: 0, dtype: object

# %%
y_train[:20]

# %%
from sklearn.svm import SVC

# %%
clf = SVC()

# %%
clf.fit(X_train, y_train)
# Out:
# SVC()

# %%
clf.score(X_test, y_test)
# Out:
# 1.0

# %%
from joblib import dump, load

# %%
dump(clf, 'asl.joblib')
# Out:
# ['asl.joblib']
